# %%
# !wget http://ufldl.stanford.edu/housenumbers/train_32x32.mat
# !wget http://ufldl.stanford.edu/housenumbers/test_32x32.mat
# Out:
# --2021-03-16 16:49:20--  http://ufldl.stanford.edu/housenumbers/train_32x32.mat
# Resolving ufldl.stanford.edu (ufldl.stanford.edu)... 171.64.68.10
# Connecting to ufldl.stanford.edu (ufldl.stanford.edu)|171.64.68.10|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 182040794 (174M) [text/plain]
# Saving to: ‘train_32x32.mat’
#
# train_32x32.mat     100%[===================>] 173.61M  57.3MB/s    in 3.0s
#
# 2021-03-16 16:49:24 (57.3 MB/s) - ‘train_32x32.mat’ saved [182040794/182040794]
#
# --2021-03-16 16:49:24--  http://ufldl.stanford.edu/housenumbers/test_32x32.mat
# Resolving ufldl.stanford.edu (ufldl.stanford.edu)... 171.64.68.10
# Connecting to ufldl.stanford.edu (ufldl.stanford.edu)|171.64.68.10|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 64275384 (61M) [text/plain]
# Saving to: ‘test_32x32.mat’
#
# test_32x32.mat      100%[===================>]  61.30M  31.9MB/s    in 1.9s
#
# 2021-03-16 16:49:26 (31.9 MB/s) - ‘test_32x32.mat’ saved [64275384/64275384]

# %%
import keras
from keras.layers.normalization import BatchNormalization
import numpy as np
import scipy.io as io
from keras.layers import Activation, Flatten,Softmax
from keras.layers import Conv2D
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import MaxPooling2D
from keras.models import Sequential
from keras import optimizers
from keras.backend import function
import pandas as pd
import tensorflow as tf

# %%
train_set = io.loadmat("train_32x32.mat")
test_set = io.loadmat("test_32x32.mat")
x_train = train_set['X']
y_train = train_set['y']
x_test = test_set['X']
y_test = test_set['y']
# Reshaping test and training data sets
x_train = np.moveaxis(x_train,[3,0,1,2],[0,1,2,3])
x_train = x_train.astype('float32')
x_test = np.moveaxis(x_test,[3,0,1,2],[0,1,2,3])
x_test = np.asarray(x_test)
x_test = x_test.astype('float32')
#Normalisation des données
x_train /= x_train.max()
x_test /= x_test.max()
# Passage de classe comme integer à classe comme vecteur de dimension classes
y_test_RN = [y-1 for y in y_test]# la classe 1 corresponds au array qui à 1 en indice 0
y_train_RN = [y-1 for y in y_train]
classes = 10
y_train_RN = keras.utils.to_categorical(y_train_RN, classes)
y_test_RN = keras.utils.to_categorical(y_test_RN, classes)
 #Définition du type de data pour optimiser la mémoire
y_train_RN = y_train_RN.astype('int32')
y_test_RN = y_test_RN.astype('int32')
# Featurewise normalization
datagen = keras.preprocessing.image.ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    horizontal_flip=False,
    zca_whitening=False, 
    zca_epsilon=1e-06)

datagen.fit(x_train)

# %%
y_test_KNN=[k.item() for k in y_test]
y_train_KNN=[k.item() for k in y_train]

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Mounted at drive

# %%
an_array=[1,2,14,6,0,9]
max_index_col = np.argmax(an_array, axis=0)
max_index_col
# Out:
# 2

# %%
def deepnet2():
  model=Sequential()
  model.add(Conv2D(64, kernel_size=(3, 3),padding = 'same', activation='relu', input_shape=x_train.shape[1:]))
  model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2),  padding = 'valid', name='S1'))
  model.add(Conv2D(128, kernel_size=(3, 3), padding = 'valid', activation='relu'))
  model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2),  padding = 'same', name='S2'))
  model.add(Conv2D(128, kernel_size=(3, 3),  strides = (1,1), padding = 'valid',  activation='relu'))
  model.add(Conv2D(128, kernel_size=(3, 3),  strides = (1,1), padding = 'valid',  activation='relu'))
  model.add(Conv2D(128, kernel_size=(3, 3),  strides = (1,1), padding = 'valid',  activation='relu'))
  model.add(Dropout(0.5)) 
  model.add(Flatten())
  model.add(Dense(classes, activation='softmax'))
  adam = optimizers.Adam(lr = 0.001)
  model.compile(loss=keras.losses.categorical_crossentropy,
                  optimizer= adam,
                  metrics=['accuracy'])
  return model

# %%
model=deepnet2()

# %%
model = keras.models.load_model('/content/drive/MyDrive/Projet 3A')

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_10 (Conv2D)           (None, 32, 32, 64)        1792
# _________________________________________________________________
# S1 (MaxPooling2D)            (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 14, 14, 128)       73856
# _________________________________________________________________
# S2 (MaxPooling2D)            (None, 7, 7, 128)         0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 5, 5, 128)         147584
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 3, 3, 128)         147584
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 1, 1, 128)         147584
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1, 1, 128)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 519,690
# Trainable params: 519,690
# Non-trainable params: 0
# _________________________________________________________________

# %%
scores=[]
x_train_10000=x_train[:10000]

# %%
def takeSecond(elem):
    return elem[1]

# %%
def somme_array(L):
  somme=np.zeros(len(L[0]))
  for l in L:
    somme=somme+l
  return somme

# %%
model.predict(x_train[0:1])[0]
# Out:
# array([9.9862885e-01, 1.3458154e-04, 2.0203834e-04, 3.1555185e-04,
#        8.8591933e-06, 5.3440385e-06, 6.0649344e-04, 3.1276793e-06,
#        7.7708155e-06, 8.7479806e-05], dtype=float32)

# %%
def ponderation(L):
  return np.exp(-1*np.array(L))

# %%
def neighbors(x,d,k):
  distance=[]
  voisin=[]
  weights=[]
  for i in range(len(d)):
    L=[i]
    L.append(np.linalg.norm(x-d[i]))
    distance.append(L)
  distance=sorted(distance,key=takeSecond)
  for j in range(k):
    voisin.append(distance[j][0])
    weights.append(distance[j][1])
  weights=ponderation(weights)
  return voisin,weights

# %%
def predict(x,d,k,model):
  voisins,weights=neighbors(x,d,k)
  neig=[]
  for i in range(len(voisins)):
    N=voisins[i]
    neig.append(weights[i]*model.predict(x_train[N:N+1])[0])
  v=somme_array(neig)
  classe=np.argmax(v, axis=0)+1
  return classe

# %%
def pred2(x,d,k,model):
  voisins,weights=neighbors(x,d,k)
  neig=[]
  for i in range(len(voisins)):
    N=voisins[i]
    neig.append(weights[i]*model.predict(x_train[N:N+1])[0])
  v=somme_array(neig)
  v[np.argmax(v, axis=0)]=0
  classe=np.argmax(v, axis=0)+1
  return classe

# %%
def pred3(x,d,k,model):
  voisins,weights=neighbors(x,d,k)
  neig=[]
  for i in range(len(voisins)):
    N=voisins[i]
    neig.append(weights[i]*model.predict(x_train[N:N+1])[0])
  v=somme_array(neig)
  v[np.argmax(v, axis=0)]=0
  v[np.argmax(v, axis=0)]=0
  classe=np.argmax(v, axis=0)+1
  return classe

# %%
def pred4(x,d,k,model):
  voisins,weights=neighbors(x,d,k)
  neig=[]
  for i in range(len(voisins)):
    N=voisins[i]
    neig.append(weights[i]*model.predict(x_train[N:N+1])[0])
  v=somme_array(neig)
  v[np.argmax(v, axis=0)]=0
  v[np.argmax(v, axis=0)]=0
  v[np.argmax(v, axis=0)]=0
  classe=np.argmax(v, axis=0)+1
  return classe

# %%
def predict_data(x_t,x_tr,k,model):
  prediction=[]
  for k in range(len(x_t)):
    prediction.append(predict(x_t[k],x_tr,k,model))
  return prediction

# %% [markdown]
# #Conv2D 50

# %%
get_conv50_output = function([model.layers[0].input],
                                  [model.layers[6].output])
layer_output_conv50 = get_conv50_output([x_train_10000])

# %%
conv50=np.array(layer_output_conv50[0]).reshape(10000,128)

# %%
layer_output_conv50_test = get_conv50_output([x_test[:5000]])

# %%
conv50_test=np.array(layer_output_conv50_test[0]).reshape(5000,128)

# %%
prediction=[]
for k in range(len(conv50_test)):
  prediction.append(predict(conv50_test[k],conv50,5,model))
prediction
# Out:
# [5,
#  2,
#  1,
#  10,
#  6,
#  1,
#  9,
#  1,
#  1,
#  8,
#  3,
#  6,
#  5,
#  1,
#  4,
#  4,
#  1,
#  6,
#  3,
#  4,
#  2,
#  10,
#  1,
#  3,
#  2,
#  5,
#  4,
#  1,
#  4,
#  2,
#  9,
#  3,
#  8,
#  6,
#  10,
#  1,
#  5,
#  1,
#  1,
#  2,
#  8,
#  1,
#  6,
#  9,
#  9,
#  8,
#  1,
#  2,
#  10,
#  6,
#  9,
#  1,
#  5,
#  1,
#  9,
#  2,
#  4,
#  5,
#  1,
#  9,
#  2,
#  9,
#  2,
#  4,
#  1,
#  10,
#  6,
#  9,
#  3,
#  2,
#  3,
#  5,
#  1,
#  1,
#  4,
#  6,
#  2,
#  6,
#  3,
#  1,
#  4,
#  1,
#  7,
#  1,
#  2,
#  1,
#  7,
#  1,
#  10,
#  1,
#  4,
#  4,
#  6,
#  4,
#  4,
#  2,
#  7,
#  1,
#  7,
#  7,
#  4,
#  8,
#  2,
#  3,
#  2,
#  2,
#  3,
#  1,
#  8,
#  6,
#  3,
#  7,
#  6,
#  5,
#  10,
#  7,
#  2,
#  7,
#  4,
#  2,
#  8,
#  8,
#  1,
#  7,
#  4,
#  9,
#  1,
#  4,
#  2,
#  9,
#  6,
#  1,
#  8,
#  10,
#  8,
#  2,
#  10,
#  1,
#  10,
#  3,
#  1,
#  2,
#  4,
#  6,
#  7,
#  2,
#  1,
#  3,
#  5,
#  3,
#  1,
#  5,
#  9,
#  1,
#  8,
#  1,
#  3,
#  6,
#  4,
#  6,
#  4,
#  9,
#  3,
#  6,
#  1,
#  10,
#  1,
#  2,
#  6,
#  2,
#  7,
#  5,
#  2,
#  2,
#  1,
#  4,
#  2,
#  9,
#  6,
#  7,
#  1,
#  10,
#  2,
#  1,
#  4,
#  8,
#  3,
#  2,
#  1,
#  6,
#  2,
#  6,
#  1,
#  7,
#  2,
#  3,
#  6,
#  1,
#  1,
#  3,
#  7,
#  2,
#  3,
#  5,
#  10,
#  2,
#  1,
#  10,
#  4,
#  7,
#  1,
#  10,
#  2,
#  3,
#  7,
#  3,
#  1,
#  1,
#  1,
#  2,
#  10,
#  4,
#  7,
#  1,
#  2,
#  3,
#  6,
#  2,
#  2,
#  9,
#  2,
#  5,
#  7,
#  4,
#  1,
#  1,
#  3,
#  4,
#  3,
#  2,
#  7,
#  1,
#  1,
#  4,
#  1,
#  7,
#  3,
#  10,
#  3,
#  6,
#  9,
#  4,
#  10,
#  3,
#  1,
#  3,
#  1,
#  5,
#  2,
#  6,
#  1,
#  8,
#  8,
#  3,
#  1,
#  9,
#  9,
#  7,
#  6,
#  1,
#  9,
#  5,
#  10,
#  3,
#  8,
#  4,
#  3,
#  1,
#  10,
#  1,
#  9,
#  2,
#  5,
#  5,
#  8,
#  9,
#  5,
#  9,
#  1,
#  10,
#  3,
#  2,
#  7,
#  8,
#  7,
#  1,
#  2,
#  9,
#  8,
#  6,
#  7,
#  2,
#  9,
#  2,
#  1,
#  3,
#  5,
#  4,
#  5,
#  3,
#  2,
#  8,
#  9,
#  3,
#  6,
#  1,
#  10,
#  8,
#  7,
#  2,
#  2,
#  1,
#  4,
#  2,
#  6,
#  1,
#  6,
#  6,
#  5,
#  10,
#  2,
#  6,
#  4,
#  1,
#  2,
#  9,
#  2,
#  1,
#  3,
#  7,
#  9,
#  4,
#  4,
#  5,
#  6,
#  9,
#  6,
#  2,
#  3,
#  6,
#  2,
#  9,
#  9,
#  4,
#  2,
#  5,
#  1,
#  6,
#  1,
#  4,
#  7,
#  7,
#  2,
#  6,
#  6,
#  9,
#  2,
#  10,
#  2,
#  1,
#  6,
#  9,
#  6,
#  3,
#  5,
#  2,
#  5,
#  6,
#  3,
#  10,
#  6,
#  7,
#  4,
#  6,
#  2,
#  1,
#  8,
#  7,
#  4,
#  4,
#  2,
#  1,
#  2,
#  4,
#  9,
#  1,
#  6,
#  7,
#  5,
#  8,
#  9,
#  9,
#  6,
#  2,
#  3,
#  2,
#  5,
#  1,
#  2,
#  4,
#  2,
#  6,
#  6,
#  2,
#  6,
#  5,
#  3,
#  1,
#  2,
#  8,
#  4,
#  2,
#  3,
#  4,
#  8,
#  4,
#  3,
#  1,
#  4,
#  1,
#  4,
#  1,
#  7,
#  5,
#  8,
#  7,
#  1,
#  10,
#  4,
#  5,
#  4,
#  7,
#  9,
#  3,
#  1,
#  2,
#  4,
#  2,
#  7,
#  1,
#  3,
#  9,
#  1,
#  8,
#  2,
#  7,
#  1,
#  7,
#  3,
#  5,
#  3,
#  2,
#  2,
#  10,
#  7,
#  4,
#  3,
#  3,
#  4,
#  3,
#  5,
#  2,
#  2,
#  2,
#  1,
#  2,
#  1,
#  2,
#  7,
#  2,
#  3,
#  5,
#  3,
#  1,
#  1,
#  4,
#  3,
#  4,
#  3,
#  3,
#  1,
#  3,
#  7,
#  1,
#  10,
#  4,
#  3,
#  6,
#  6,
#  2,
#  9,
#  1,
#  9,
#  1,
#  10,
#  1,
#  5,
#  4,
#  7,
#  1,
#  5,
#  5,
#  3,
#  2,
#  8,
#  9,
#  4,
#  5,
#  7,
#  6,
#  2,
#  2,
#  1,
#  7,
#  1,
#  10,
#  1,
#  4,
#  1,
#  1,
#  3,
#  1,
#  5,
#  4,
#  2,
#  1,
#  2,
#  1,
#  2,
#  1,
#  6,
#  9,
#  2,
#  5,
#  4,
#  10,
#  2,
#  2,
#  3,
#  1,
#  9,
#  5,
#  7,
#  4,
#  5,
#  8,
#  2,
#  4,
#  10,
#  1,
#  5,
#  2,
#  10,
#  5,
#  5,
#  8,
#  5,
#  7,
#  3,
#  5,
#  9,
#  5,
#  3,
#  7,
#  2,
#  4,
#  2,
#  7,
#  3,
#  10,
#  4,
#  2,
#  2,
#  1,
#  9,
#  6,
#  2,
#  1,
#  3,
#  4,
#  5,
#  3,
#  3,
#  1,
#  9,
#  2,
#  6,
#  2,
#  4,
#  10,
#  9,
#  1,
#  6,
#  1,
#  10,
#  9,
#  2,
#  10,
#  5,
#  2,
#  4,
#  10,
#  8,
#  1,
#  10,
#  2,
#  10,
#  7,
#  2,
#  7,
#  7,
#  2,
#  5,
#  5,
#  6,
#  1,
#  5,
#  4,
#  2,
#  2,
#  7,
#  5,
#  1,
#  9,
#  1,
#  7,
#  7,
#  1,
#  5,
#  1,
#  2,
#  1,
#  2,
#  7,
#  2,
#  3,
#  6,
#  3,
#  7,
#  4,
#  7,
#  2,
#  8,
#  6,
#  8,
#  1,
#  6,
#  4,
#  7,
#  3,
#  1,
#  5,
#  3,
#  5,
#  4,
#  2,
#  7,
#  3,
#  9,
#  2,
#  7,
#  8,
#  10,
#  3,
#  10,
#  5,
#  9,
#  7,
#  9,
#  1,
#  7,
#  8,
#  4,
#  1,
#  2,
#  7,
#  6,
#  2,
#  8,
#  1,
#  1,
#  5,
#  9,
#  4,
#  9,
#  4,
#  6,
#  1,
#  2,
#  2,
#  1,
#  5,
#  2,
#  6,
#  6,
#  2,
#  6,
#  8,
#  3,
#  8,
#  3,
#  3,
#  7,
#  2,
#  7,
#  3,
#  3,
#  8,
#  2,
#  10,
#  1,
#  3,
#  1,
#  2,
#  4,
#  2,
#  3,
#  6,
#  2,
#  1,
#  1,
#  6,
#  1,
#  3,
#  5,
#  2,
#  4,
#  4,
#  4,
#  1,
#  5,
#  1,
#  1,
#  1,
#  10,
#  2,
#  7,
#  1,
#  8,
#  5,
#  4,
#  3,
#  3,
#  6,
#  4,
#  4,
#  3,
#  10,
#  6,
#  1,
#  7,
#  6,
#  2,
#  2,
#  1,
#  9,
#  1,
#  8,
#  1,
#  3,
#  9,
#  2,
#  9,
#  1,
#  4,
#  4,
#  9,
#  3,
#  4,
#  5,
#  1,
#  1,
#  4,
#  6,
#  6,
#  5,
#  1,
#  1,
#  10,
#  1,
#  6,
#  9,
#  1,
#  1,
#  5,
#  5,
#  7,
#  10,
#  3,
#  9,
#  3,
#  6,
#  1,
#  2,
#  5,
#  2,
#  10,
#  9,
#  1,
#  3,
#  6,
#  7,
#  2,
#  9,
#  10,
#  5,
#  1,
#  7,
#  4,
#  1,
#  5,
#  5,
#  1,
#  6,
#  3,
#  10,
#  2,
#  10,
#  6,
#  2,
#  8,
#  1,
#  2,
#  2,
#  1,
#  10,
#  5,
#  5,
#  2,
#  3,
#  7,
#  8,
#  2,
#  6,
#  2,
#  5,
#  3,
#  3,
#  1,
#  5,
#  2,
#  3,
#  1,
#  10,
#  1,
#  6,
#  1,
#  5,
#  1,
#  5,
#  6,
#  8,
#  10,
#  1,
#  10,
#  4,
#  1,
#  3,
#  5,
#  3,
#  3,
#  1,
#  10,
#  3,
#  4,
#  4,
#  1,
#  5,
#  1,
#  1,
#  3,
#  1,
#  6,
#  4,
#  10,
#  3,
#  3,
#  2,
#  10,
#  8,
#  6,
#  2,
#  6,
#  1,
#  8,
#  5,
#  2,
#  3,
#  10,
#  2,
#  1,
#  1,
#  2,
#  3,
#  6,
#  10,
#  2,
#  5,
#  8,
#  5,
#  1,
#  9,
#  7,
#  6,
#  8,
#  5,
#  2,
#  2,
#  1,
#  7,
#  2,
#  8,
#  4,
#  1,
#  9,
#  4,
#  2,
#  4,
#  9,
#  8,
#  2,
#  3,
#  2,
#  3,
#  7,
#  2,
#  3,
#  4,
#  2,
#  10,
#  10,
#  3,
#  3,
#  3,
#  1,
#  2,
#  3,
#  5,
#  3,
#  6,
#  3,
#  6,
#  1,
#  8,
#  9,
#  1,
#  10,
#  6,
#  5,
#  1,
#  10,
#  7,
#  2,
#  1,
#  1,
#  10,
#  1,
#  10,
#  3,
#  2,
#  2,
#  2,
#  1,
#  1,
#  1,
#  10,
#  2,
#  7,
#  7,
#  3,
#  7,
#  7,
#  5,
#  9,
#  3,
#  9,
#  1,
#  9,
#  5,
#  2,
#  10,
#  2,
#  1,
#  4,
#  1,
#  4,
#  1,
#  5,
#  1,
#  5,
#  ...]

# %%
wrong=[]
for k in range(5000):
  if prediction[k]!=y_test_KNN[k]:
    wrong.append(k)

# %%
i=0
j=0
t=0
for k in wrong:
  if pred2(conv50_test[k],conv50,5,model)==y_test_KNN[k]:
    i=i+1
  elif pred3(conv50_test[k],conv50,5,model)==y_test_KNN[k]:
    j=j+1
  elif pred4(conv50_test[k],conv50,5,model)==y_test_KNN[k]:
    t=t+1

# %% [markdown]
# # Conv2D 40

# %%
get_conv40_output = function([model.layers[0].input],
                                  [model.layers[5].output])
layer_output_conv40 = get_conv40_output([x_train_10000])

# %%
conv40=np.array(layer_output_conv40[0]).reshape(10000,1152)

# %%
layer_output_conv40_test = get_conv40_output([x_test[:5000]])

# %%
conv40_test=np.array(layer_output_conv40_test[0]).reshape(5000,1152)

# %%
prediction=[]
for k in range(len(conv40_test)):
  prediction.append(predict(conv40_test[k],conv40,5,model))
prediction
# Out:
# [5,
#  2,
#  1,
#  10,
#  6,
#  1,
#  9,
#  1,
#  1,
#  8,
#  3,
#  8,
#  5,
#  1,
#  4,
#  4,
#  1,
#  6,
#  3,
#  4,
#  2,
#  10,
#  1,
#  9,
#  2,
#  5,
#  4,
#  1,
#  4,
#  9,
#  9,
#  3,
#  5,
#  6,
#  10,
#  1,
#  5,
#  1,
#  1,
#  2,
#  9,
#  1,
#  6,
#  9,
#  9,
#  4,
#  1,
#  2,
#  10,
#  6,
#  9,
#  1,
#  5,
#  1,
#  9,
#  2,
#  4,
#  5,
#  1,
#  5,
#  2,
#  9,
#  2,
#  4,
#  1,
#  1,
#  10,
#  9,
#  3,
#  2,
#  3,
#  5,
#  1,
#  1,
#  4,
#  6,
#  2,
#  6,
#  3,
#  1,
#  4,
#  1,
#  7,
#  1,
#  2,
#  1,
#  7,
#  1,
#  10,
#  1,
#  4,
#  4,
#  6,
#  4,
#  4,
#  2,
#  7,
#  1,
#  7,
#  7,
#  4,
#  8,
#  2,
#  3,
#  2,
#  2,
#  3,
#  1,
#  8,
#  6,
#  3,
#  7,
#  6,
#  3,
#  10,
#  7,
#  2,
#  1,
#  4,
#  2,
#  8,
#  8,
#  1,
#  7,
#  4,
#  10,
#  1,
#  4,
#  2,
#  9,
#  6,
#  1,
#  6,
#  9,
#  8,
#  2,
#  10,
#  1,
#  10,
#  3,
#  1,
#  2,
#  4,
#  6,
#  7,
#  2,
#  1,
#  3,
#  5,
#  3,
#  1,
#  5,
#  9,
#  1,
#  8,
#  1,
#  8,
#  6,
#  4,
#  6,
#  4,
#  9,
#  3,
#  6,
#  1,
#  10,
#  1,
#  2,
#  5,
#  2,
#  7,
#  8,
#  2,
#  2,
#  1,
#  4,
#  2,
#  9,
#  6,
#  7,
#  1,
#  10,
#  2,
#  1,
#  4,
#  8,
#  3,
#  2,
#  1,
#  6,
#  2,
#  6,
#  1,
#  7,
#  2,
#  3,
#  6,
#  1,
#  1,
#  3,
#  7,
#  2,
#  1,
#  5,
#  10,
#  2,
#  1,
#  10,
#  4,
#  7,
#  1,
#  10,
#  2,
#  3,
#  7,
#  3,
#  1,
#  1,
#  1,
#  2,
#  10,
#  1,
#  7,
#  1,
#  2,
#  1,
#  6,
#  2,
#  2,
#  9,
#  2,
#  5,
#  7,
#  4,
#  1,
#  1,
#  3,
#  4,
#  3,
#  3,
#  7,
#  1,
#  1,
#  4,
#  1,
#  7,
#  1,
#  10,
#  3,
#  10,
#  9,
#  4,
#  10,
#  3,
#  2,
#  3,
#  1,
#  5,
#  2,
#  6,
#  1,
#  8,
#  8,
#  3,
#  3,
#  9,
#  9,
#  7,
#  6,
#  1,
#  9,
#  1,
#  10,
#  3,
#  8,
#  2,
#  3,
#  1,
#  10,
#  1,
#  9,
#  2,
#  5,
#  5,
#  8,
#  9,
#  5,
#  9,
#  1,
#  10,
#  3,
#  2,
#  1,
#  6,
#  7,
#  1,
#  2,
#  9,
#  8,
#  6,
#  7,
#  2,
#  9,
#  2,
#  1,
#  3,
#  5,
#  4,
#  5,
#  3,
#  2,
#  8,
#  9,
#  3,
#  6,
#  1,
#  10,
#  8,
#  2,
#  2,
#  2,
#  1,
#  4,
#  2,
#  6,
#  1,
#  6,
#  6,
#  5,
#  10,
#  2,
#  6,
#  4,
#  1,
#  2,
#  4,
#  2,
#  1,
#  3,
#  7,
#  9,
#  4,
#  4,
#  5,
#  6,
#  9,
#  4,
#  2,
#  3,
#  6,
#  2,
#  9,
#  9,
#  4,
#  2,
#  5,
#  1,
#  6,
#  1,
#  4,
#  7,
#  1,
#  1,
#  6,
#  6,
#  9,
#  2,
#  10,
#  2,
#  1,
#  6,
#  9,
#  6,
#  1,
#  4,
#  2,
#  5,
#  10,
#  3,
#  10,
#  6,
#  7,
#  4,
#  8,
#  2,
#  1,
#  6,
#  7,
#  4,
#  4,
#  2,
#  1,
#  2,
#  4,
#  9,
#  1,
#  6,
#  1,
#  5,
#  8,
#  9,
#  9,
#  6,
#  3,
#  9,
#  2,
#  5,
#  1,
#  2,
#  2,
#  3,
#  6,
#  6,
#  2,
#  6,
#  5,
#  3,
#  1,
#  2,
#  8,
#  4,
#  2,
#  2,
#  4,
#  3,
#  4,
#  3,
#  1,
#  4,
#  1,
#  4,
#  1,
#  1,
#  5,
#  8,
#  7,
#  1,
#  10,
#  4,
#  3,
#  4,
#  7,
#  9,
#  3,
#  1,
#  2,
#  4,
#  2,
#  7,
#  1,
#  3,
#  9,
#  1,
#  8,
#  2,
#  7,
#  1,
#  7,
#  3,
#  5,
#  3,
#  2,
#  2,
#  10,
#  7,
#  4,
#  5,
#  3,
#  4,
#  3,
#  5,
#  2,
#  2,
#  2,
#  1,
#  2,
#  1,
#  2,
#  7,
#  2,
#  3,
#  3,
#  3,
#  1,
#  1,
#  4,
#  3,
#  4,
#  3,
#  3,
#  1,
#  3,
#  7,
#  1,
#  10,
#  4,
#  3,
#  6,
#  6,
#  2,
#  9,
#  1,
#  3,
#  9,
#  10,
#  1,
#  3,
#  4,
#  7,
#  1,
#  5,
#  5,
#  3,
#  2,
#  8,
#  9,
#  4,
#  5,
#  7,
#  6,
#  2,
#  2,
#  1,
#  1,
#  1,
#  10,
#  1,
#  4,
#  9,
#  7,
#  3,
#  1,
#  5,
#  4,
#  2,
#  4,
#  2,
#  1,
#  2,
#  1,
#  6,
#  9,
#  2,
#  5,
#  4,
#  10,
#  2,
#  10,
#  3,
#  1,
#  9,
#  5,
#  7,
#  4,
#  5,
#  8,
#  2,
#  4,
#  10,
#  1,
#  5,
#  2,
#  10,
#  5,
#  5,
#  8,
#  5,
#  7,
#  6,
#  5,
#  9,
#  5,
#  3,
#  7,
#  2,
#  4,
#  2,
#  7,
#  3,
#  10,
#  4,
#  2,
#  2,
#  1,
#  9,
#  6,
#  2,
#  1,
#  3,
#  4,
#  5,
#  3,
#  3,
#  1,
#  9,
#  2,
#  6,
#  2,
#  4,
#  10,
#  9,
#  1,
#  6,
#  1,
#  10,
#  9,
#  2,
#  10,
#  6,
#  2,
#  4,
#  10,
#  8,
#  1,
#  10,
#  2,
#  10,
#  7,
#  2,
#  7,
#  7,
#  2,
#  5,
#  5,
#  6,
#  1,
#  5,
#  1,
#  2,
#  2,
#  7,
#  5,
#  1,
#  9,
#  1,
#  7,
#  7,
#  1,
#  5,
#  1,
#  2,
#  1,
#  2,
#  2,
#  2,
#  3,
#  6,
#  3,
#  7,
#  4,
#  7,
#  2,
#  8,
#  6,
#  8,
#  1,
#  4,
#  4,
#  7,
#  3,
#  1,
#  5,
#  5,
#  5,
#  4,
#  2,
#  1,
#  3,
#  9,
#  2,
#  3,
#  8,
#  10,
#  3,
#  10,
#  5,
#  9,
#  7,
#  9,
#  1,
#  7,
#  8,
#  4,
#  1,
#  2,
#  7,
#  6,
#  2,
#  8,
#  1,
#  1,
#  5,
#  9,
#  4,
#  9,
#  4,
#  6,
#  1,
#  2,
#  2,
#  1,
#  5,
#  2,
#  4,
#  6,
#  2,
#  6,
#  8,
#  3,
#  8,
#  3,
#  2,
#  7,
#  2,
#  7,
#  3,
#  3,
#  8,
#  2,
#  10,
#  1,
#  3,
#  1,
#  2,
#  4,
#  2,
#  3,
#  6,
#  2,
#  1,
#  1,
#  6,
#  1,
#  3,
#  5,
#  2,
#  4,
#  4,
#  4,
#  1,
#  5,
#  1,
#  1,
#  1,
#  10,
#  2,
#  7,
#  1,
#  8,
#  5,
#  4,
#  3,
#  8,
#  6,
#  4,
#  4,
#  3,
#  10,
#  6,
#  1,
#  7,
#  6,
#  2,
#  3,
#  1,
#  9,
#  1,
#  8,
#  1,
#  3,
#  9,
#  2,
#  9,
#  1,
#  4,
#  4,
#  9,
#  3,
#  4,
#  5,
#  1,
#  1,
#  2,
#  3,
#  3,
#  5,
#  1,
#  1,
#  10,
#  1,
#  6,
#  10,
#  1,
#  1,
#  5,
#  5,
#  7,
#  10,
#  3,
#  9,
#  3,
#  6,
#  1,
#  2,
#  5,
#  2,
#  10,
#  9,
#  1,
#  3,
#  6,
#  7,
#  2,
#  9,
#  10,
#  5,
#  1,
#  7,
#  4,
#  1,
#  5,
#  3,
#  10,
#  6,
#  3,
#  10,
#  2,
#  1,
#  6,
#  2,
#  8,
#  1,
#  2,
#  2,
#  1,
#  10,
#  5,
#  5,
#  2,
#  3,
#  7,
#  8,
#  2,
#  6,
#  2,
#  5,
#  3,
#  3,
#  1,
#  5,
#  2,
#  9,
#  1,
#  10,
#  1,
#  6,
#  1,
#  5,
#  1,
#  5,
#  6,
#  8,
#  1,
#  1,
#  10,
#  4,
#  1,
#  5,
#  5,
#  3,
#  3,
#  1,
#  10,
#  3,
#  4,
#  4,
#  1,
#  3,
#  1,
#  1,
#  3,
#  1,
#  6,
#  4,
#  10,
#  3,
#  3,
#  2,
#  10,
#  8,
#  6,
#  2,
#  6,
#  1,
#  8,
#  5,
#  2,
#  5,
#  10,
#  2,
#  1,
#  1,
#  2,
#  3,
#  6,
#  10,
#  2,
#  5,
#  8,
#  5,
#  1,
#  9,
#  7,
#  6,
#  8,
#  5,
#  2,
#  2,
#  1,
#  7,
#  2,
#  8,
#  4,
#  1,
#  9,
#  4,
#  2,
#  4,
#  9,
#  6,
#  2,
#  3,
#  2,
#  3,
#  7,
#  2,
#  3,
#  4,
#  2,
#  10,
#  10,
#  3,
#  5,
#  3,
#  1,
#  2,
#  3,
#  5,
#  3,
#  6,
#  3,
#  6,
#  1,
#  1,
#  9,
#  1,
#  10,
#  6,
#  5,
#  1,
#  10,
#  7,
#  2,
#  1,
#  1,
#  10,
#  1,
#  10,
#  3,
#  2,
#  2,
#  2,
#  6,
#  1,
#  1,
#  10,
#  2,
#  7,
#  3,
#  3,
#  7,
#  1,
#  5,
#  9,
#  3,
#  9,
#  1,
#  5,
#  5,
#  2,
#  10,
#  2,
#  1,
#  4,
#  1,
#  4,
#  1,
#  5,
#  1,
#  5,
#  ...]

# %%
wrong=[]
for k in range(5000):
  if prediction[k]!=y_test_KNN[k]:
    wrong.append(k)

# %%
i=0
j=0
t=0
for k in wrong:
  if pred2(conv40_test[k],conv40,5,model)==y_test_KNN[k]:
    i=i+1
  elif pred3(conv40_test[k],conv40,5,model)==y_test_KNN[k]:
    j=j+1
  elif pred4(conv40_test[k],conv40,5,model)==y_test_KNN[k]:
    t=t+1

# %% [markdown]
# #Conv2D 30

# %%
get_conv30_output = function([model.layers[0].input],
                                  [model.layers[4].output])
layer_output_conv30 = get_conv30_output([x_train_10000])

# %%
conv30=np.array(layer_output_conv30[0]).reshape(10000,3200)

# %%
layer_output_conv30_test = get_conv30_output([x_test[:5000]])

# %%
conv30_test=np.array(layer_output_conv30_test[0]).reshape(5000,3200)

# %%
prediction=[]
for k in range(len(conv30_test)):
  prediction.append(predict(conv30_test[k],conv30,5,model))
prediction
# Out:
# [5,
#  2,
#  1,
#  10,
#  6,
#  1,
#  9,
#  1,
#  1,
#  8,
#  3,
#  6,
#  5,
#  1,
#  4,
#  4,
#  1,
#  10,
#  3,
#  4,
#  2,
#  10,
#  1,
#  3,
#  2,
#  5,
#  4,
#  1,
#  4,
#  2,
#  10,
#  3,
#  6,
#  6,
#  10,
#  1,
#  5,
#  1,
#  1,
#  2,
#  2,
#  1,
#  6,
#  5,
#  2,
#  6,
#  1,
#  2,
#  10,
#  6,
#  9,
#  1,
#  5,
#  1,
#  9,
#  6,
#  4,
#  5,
#  7,
#  5,
#  2,
#  9,
#  2,
#  4,
#  1,
#  9,
#  10,
#  9,
#  3,
#  2,
#  3,
#  5,
#  1,
#  1,
#  4,
#  6,
#  2,
#  5,
#  3,
#  1,
#  4,
#  1,
#  7,
#  1,
#  2,
#  1,
#  7,
#  1,
#  10,
#  1,
#  4,
#  4,
#  6,
#  4,
#  4,
#  2,
#  7,
#  1,
#  7,
#  7,
#  4,
#  8,
#  2,
#  5,
#  2,
#  2,
#  3,
#  1,
#  5,
#  6,
#  3,
#  7,
#  6,
#  5,
#  9,
#  7,
#  2,
#  7,
#  10,
#  2,
#  8,
#  8,
#  1,
#  1,
#  1,
#  10,
#  1,
#  4,
#  2,
#  2,
#  6,
#  8,
#  6,
#  9,
#  8,
#  2,
#  9,
#  1,
#  10,
#  3,
#  2,
#  2,
#  4,
#  6,
#  7,
#  2,
#  1,
#  3,
#  5,
#  3,
#  1,
#  5,
#  9,
#  1,
#  8,
#  1,
#  10,
#  6,
#  1,
#  6,
#  4,
#  9,
#  3,
#  6,
#  1,
#  6,
#  1,
#  2,
#  6,
#  2,
#  7,
#  2,
#  2,
#  2,
#  1,
#  4,
#  2,
#  9,
#  6,
#  7,
#  1,
#  10,
#  2,
#  1,
#  4,
#  8,
#  3,
#  2,
#  1,
#  6,
#  2,
#  6,
#  1,
#  7,
#  7,
#  3,
#  6,
#  1,
#  1,
#  3,
#  7,
#  2,
#  3,
#  5,
#  10,
#  2,
#  1,
#  10,
#  4,
#  7,
#  1,
#  10,
#  2,
#  3,
#  7,
#  3,
#  1,
#  1,
#  1,
#  2,
#  10,
#  2,
#  7,
#  1,
#  2,
#  9,
#  1,
#  2,
#  2,
#  9,
#  2,
#  5,
#  7,
#  4,
#  1,
#  7,
#  7,
#  6,
#  3,
#  3,
#  7,
#  4,
#  1,
#  4,
#  1,
#  7,
#  1,
#  10,
#  3,
#  10,
#  9,
#  4,
#  10,
#  3,
#  2,
#  3,
#  1,
#  5,
#  2,
#  6,
#  1,
#  8,
#  8,
#  3,
#  1,
#  9,
#  9,
#  7,
#  5,
#  1,
#  9,
#  2,
#  10,
#  3,
#  10,
#  2,
#  3,
#  1,
#  10,
#  1,
#  9,
#  2,
#  5,
#  5,
#  8,
#  9,
#  5,
#  9,
#  1,
#  10,
#  3,
#  2,
#  1,
#  6,
#  7,
#  1,
#  2,
#  9,
#  8,
#  6,
#  7,
#  2,
#  9,
#  2,
#  3,
#  2,
#  5,
#  4,
#  5,
#  3,
#  2,
#  8,
#  9,
#  3,
#  6,
#  1,
#  10,
#  8,
#  1,
#  2,
#  2,
#  1,
#  4,
#  2,
#  6,
#  1,
#  6,
#  6,
#  5,
#  10,
#  2,
#  6,
#  4,
#  1,
#  2,
#  4,
#  2,
#  1,
#  3,
#  2,
#  5,
#  4,
#  4,
#  5,
#  6,
#  9,
#  4,
#  2,
#  9,
#  6,
#  2,
#  9,
#  9,
#  4,
#  2,
#  5,
#  1,
#  6,
#  1,
#  4,
#  7,
#  1,
#  4,
#  6,
#  6,
#  9,
#  2,
#  10,
#  2,
#  1,
#  6,
#  9,
#  5,
#  1,
#  4,
#  2,
#  5,
#  6,
#  8,
#  10,
#  10,
#  7,
#  4,
#  6,
#  2,
#  1,
#  5,
#  7,
#  4,
#  4,
#  2,
#  1,
#  2,
#  2,
#  9,
#  1,
#  6,
#  2,
#  9,
#  8,
#  9,
#  9,
#  5,
#  2,
#  9,
#  2,
#  5,
#  1,
#  2,
#  4,
#  2,
#  6,
#  6,
#  2,
#  6,
#  5,
#  3,
#  1,
#  2,
#  5,
#  4,
#  2,
#  3,
#  3,
#  1,
#  4,
#  3,
#  1,
#  4,
#  1,
#  4,
#  1,
#  1,
#  3,
#  4,
#  7,
#  1,
#  10,
#  4,
#  5,
#  4,
#  7,
#  9,
#  3,
#  1,
#  2,
#  4,
#  2,
#  7,
#  1,
#  3,
#  9,
#  1,
#  8,
#  2,
#  7,
#  1,
#  7,
#  5,
#  5,
#  3,
#  2,
#  2,
#  9,
#  7,
#  4,
#  9,
#  3,
#  4,
#  5,
#  4,
#  1,
#  2,
#  2,
#  1,
#  2,
#  1,
#  2,
#  7,
#  2,
#  3,
#  5,
#  3,
#  1,
#  1,
#  4,
#  3,
#  4,
#  3,
#  3,
#  1,
#  3,
#  7,
#  1,
#  10,
#  4,
#  3,
#  6,
#  6,
#  2,
#  9,
#  1,
#  6,
#  8,
#  10,
#  1,
#  5,
#  4,
#  2,
#  1,
#  5,
#  5,
#  3,
#  2,
#  8,
#  5,
#  4,
#  5,
#  7,
#  6,
#  1,
#  10,
#  1,
#  1,
#  1,
#  10,
#  1,
#  4,
#  1,
#  2,
#  3,
#  1,
#  5,
#  4,
#  2,
#  1,
#  2,
#  1,
#  2,
#  1,
#  5,
#  9,
#  2,
#  5,
#  4,
#  10,
#  2,
#  10,
#  5,
#  1,
#  9,
#  5,
#  7,
#  4,
#  5,
#  6,
#  2,
#  4,
#  10,
#  1,
#  5,
#  2,
#  10,
#  3,
#  5,
#  8,
#  5,
#  1,
#  3,
#  3,
#  10,
#  3,
#  3,
#  7,
#  2,
#  4,
#  1,
#  7,
#  3,
#  10,
#  4,
#  1,
#  2,
#  1,
#  9,
#  6,
#  2,
#  1,
#  3,
#  4,
#  5,
#  3,
#  3,
#  1,
#  9,
#  2,
#  6,
#  2,
#  4,
#  10,
#  9,
#  1,
#  6,
#  1,
#  10,
#  2,
#  2,
#  10,
#  5,
#  2,
#  4,
#  10,
#  8,
#  1,
#  5,
#  2,
#  10,
#  1,
#  2,
#  7,
#  7,
#  2,
#  5,
#  5,
#  6,
#  1,
#  5,
#  1,
#  2,
#  2,
#  7,
#  5,
#  1,
#  3,
#  1,
#  7,
#  7,
#  1,
#  5,
#  1,
#  2,
#  1,
#  2,
#  2,
#  2,
#  3,
#  6,
#  3,
#  7,
#  4,
#  7,
#  2,
#  8,
#  6,
#  8,
#  1,
#  4,
#  4,
#  7,
#  9,
#  1,
#  5,
#  5,
#  5,
#  4,
#  2,
#  1,
#  3,
#  9,
#  2,
#  3,
#  8,
#  10,
#  3,
#  10,
#  5,
#  2,
#  7,
#  9,
#  1,
#  7,
#  8,
#  4,
#  1,
#  2,
#  7,
#  6,
#  2,
#  8,
#  1,
#  1,
#  5,
#  9,
#  4,
#  9,
#  4,
#  6,
#  1,
#  2,
#  2,
#  1,
#  5,
#  2,
#  4,
#  6,
#  2,
#  6,
#  4,
#  3,
#  8,
#  3,
#  1,
#  7,
#  4,
#  7,
#  3,
#  3,
#  8,
#  2,
#  10,
#  1,
#  10,
#  1,
#  2,
#  4,
#  2,
#  3,
#  6,
#  2,
#  1,
#  1,
#  6,
#  1,
#  3,
#  5,
#  2,
#  4,
#  4,
#  4,
#  1,
#  5,
#  1,
#  1,
#  1,
#  10,
#  7,
#  7,
#  1,
#  8,
#  5,
#  4,
#  3,
#  8,
#  6,
#  4,
#  4,
#  3,
#  10,
#  6,
#  1,
#  7,
#  6,
#  2,
#  8,
#  1,
#  3,
#  1,
#  8,
#  1,
#  5,
#  9,
#  2,
#  9,
#  1,
#  4,
#  6,
#  9,
#  5,
#  4,
#  5,
#  1,
#  1,
#  2,
#  5,
#  3,
#  1,
#  1,
#  1,
#  6,
#  1,
#  6,
#  10,
#  1,
#  1,
#  5,
#  3,
#  1,
#  10,
#  3,
#  9,
#  3,
#  6,
#  1,
#  2,
#  5,
#  2,
#  10,
#  3,
#  1,
#  2,
#  6,
#  7,
#  2,
#  9,
#  10,
#  4,
#  1,
#  7,
#  4,
#  1,
#  5,
#  5,
#  1,
#  6,
#  3,
#  10,
#  2,
#  2,
#  6,
#  1,
#  8,
#  1,
#  2,
#  2,
#  1,
#  10,
#  5,
#  5,
#  2,
#  3,
#  7,
#  8,
#  2,
#  6,
#  2,
#  5,
#  3,
#  3,
#  1,
#  5,
#  1,
#  10,
#  1,
#  10,
#  1,
#  6,
#  1,
#  5,
#  1,
#  5,
#  6,
#  2,
#  10,
#  4,
#  10,
#  4,
#  1,
#  3,
#  5,
#  3,
#  3,
#  1,
#  10,
#  9,
#  4,
#  10,
#  10,
#  5,
#  1,
#  1,
#  3,
#  1,
#  5,
#  4,
#  10,
#  5,
#  9,
#  2,
#  10,
#  8,
#  6,
#  2,
#  6,
#  1,
#  6,
#  5,
#  2,
#  5,
#  9,
#  2,
#  1,
#  1,
#  2,
#  3,
#  6,
#  10,
#  2,
#  5,
#  8,
#  5,
#  1,
#  5,
#  7,
#  6,
#  8,
#  5,
#  2,
#  2,
#  1,
#  7,
#  2,
#  2,
#  4,
#  1,
#  9,
#  4,
#  2,
#  4,
#  10,
#  6,
#  2,
#  8,
#  2,
#  3,
#  7,
#  2,
#  3,
#  4,
#  2,
#  10,
#  10,
#  5,
#  3,
#  3,
#  7,
#  2,
#  3,
#  5,
#  3,
#  6,
#  8,
#  6,
#  10,
#  9,
#  9,
#  1,
#  1,
#  6,
#  5,
#  1,
#  10,
#  7,
#  2,
#  1,
#  1,
#  10,
#  1,
#  10,
#  3,
#  2,
#  2,
#  1,
#  4,
#  1,
#  1,
#  10,
#  2,
#  7,
#  3,
#  3,
#  2,
#  2,
#  5,
#  9,
#  3,
#  9,
#  1,
#  5,
#  5,
#  2,
#  10,
#  2,
#  1,
#  4,
#  1,
#  4,
#  1,
#  5,
#  1,
#  5,
#  ...]

# %%
wrong=[]
for k in range(5000):
  if prediction[k]!=y_test_KNN[k]:
    wrong.append(k)

# %%
len(wrong)
# Out:
# 842

# %%
i=0
j=0
t=0
for k in wrong:
  if pred2(conv30_test[k],conv30,5,model)==y_test_KNN[k]:
    i=i+1
  elif pred3(conv30_test[k],conv30,5,model)==y_test_KNN[k]:
    j=j+1
  elif pred4(conv30_test[k],conv30,5,model)==y_test_KNN[k]:
    t=t+1

# %% [markdown]
# # Maxpooling S2

# %%
get_S2_output = function([model.layers[0].input],
                                  [model.layers[3].output])
layer_output_S2 = get_S2_output([x_train_10000])

# %%
S2=np.array(layer_output_S2[0]).reshape(10000,6272)

# %%
layer_output_S2_test = get_S2_output([x_test[:5000]])

# %%
S2_test=np.array(layer_output_S2_test[0]).reshape(5000,6272)

# %%
prediction=[]
for k in range(len(S2_test)):
  prediction.append(predict(S2_test[k],S2,5,model))
prediction

# %%
wrong=[]
for k in range(5000):
  if prediction[k]!=y_test_KNN[k]:
    wrong.append(k)

# %%
i=0
j=0
t=0
for k in wrong:
  if pred2(S2_test[k],S2,5,model)==y_test_KNN[k]:
    i=i+1
  elif pred3(S2_test[k],S2,5,model)==y_test_KNN[k]:
    j=j+1
  elif pred4(S2_test[k],S2,5,model)==y_test_KNN[k]:
    t=t+1

# %% [markdown]
# #Conv2D 20

# %%
get_conv20_output = function([model.layers[0].input],
                                  [model.layers[2].output])
layer_output_conv20 = get_conv20_output([x_train_10000])

# %%
conv20=np.array(layer_output_conv20[0]).reshape(10000,25088)

# %%
layer_output_conv20_test = get_conv20_output([x_test[:5000]])

# %%
conv20_test=np.array(layer_output_conv20_test[0]).reshape(5000,25088)

# %%
prediction=[]
for k in range(len(conv20_test)):
  prediction.append(predict(conv20_test[k],conv20,5,model))
prediction

# %%
wrong=[]
for k in range(5000):
  if prediction[k]!=y_test_KNN[k]:
    wrong.append(k)

# %%
len(wrong)
# Out:
# 1594

# %%
i=0
j=0
t=0
for k in wrong:
  if pred2(conv20_test[k],conv20,5,model)==y_test_KNN[k]:
    i=i+1
  elif pred3(conv20_test[k],conv20,5,model)==y_test_KNN[k]:
    j=j+1
  elif pred4(conv20_test[k],conv20,5,model)==y_test_KNN[k]:
    t=t+1
